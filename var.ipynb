# %%
ism = "Aziz" # str
yosh = 20 # int
boy = 1.75 # float
talaba = True # bool

# %%
print(ism)
print(yosh)
# Out:
# Aziz
# 20

# %%
print(type(ism))
# Out:
# <class 'str'>

# %%
a, b, c = 1, 2, 3
print(a, b, c)
# Out:
# 1 2 3

# %%
x = y = z = 0
print(x, y, z)
# Out:
# 0 0 0

# %%
son1 = 10
son2 = 3
# print(son1 + son2) # qo'shish
# print(son1 - son2) # ayirish
# print(son1 * son2) # ko'paytirish
# print(son1 / son2) # bo'lish
print(son1 % son2) # qoldiq
print(son1 ** 3) # daraja
# Out:
# 1
# 1000

# %%
ism = 'Aziz'
familiya = 'Valiyev'
print(ism + " " + familiya) # qo'shish
# Out:
# Aziz Valiyev

# %%
ism = 'Aziz'
yosh = 20
print(f'Mening ismim {ism}, yoshim {yosh} da.') # f-string
# Out:
# Mening ismim Aziz, yoshim 20 da.

# %%
ism = input("Ismingizni kiriting: ")
yosh = int(input("Yoshingizni kiriting: "))

print(f'Salom, {ism}! Siz {yosh} yoshdasiz.')
print('salom')
# Out:
# Salom, Mironshoh! Siz 22 yoshdasiz.
